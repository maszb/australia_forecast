# %%
import missingno as msno
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
full_data = pd.read_csv('weatherAUS.csv')
full_data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
full_data.shape
# Out:
# (145460, 23)

# %%
for col in full_data.columns.tolist():
    print(col)
# Out:
# Date
# Location
# MinTemp
# MaxTemp
# Rainfall
# Evaporation
# Sunshine
# WindGustDir
# WindGustSpeed
# WindDir9am
# WindDir3pm
# WindSpeed9am
# WindSpeed3pm
# Humidity9am
# Humidity3pm
# Pressure9am
# Pressure3pm
# Cloud9am
# Cloud3pm
# Temp9am
# Temp3pm
# RainToday
# RainTomorrow

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
full_data.drop(full_data[full_data['year'] == 2007].index, inplace = True, axis=0)
full_data.drop(full_data[full_data['year'] == 2008].index, inplace = True, axis=0)

# %%
full_data=full_data.drop('Temp9am',axis=1)
full_data=full_data.drop('Temp3pm',axis=1)
full_data=full_data.drop('WindDir9am',axis=1)
full_data=full_data.drop('WindDir3pm',axis=1)
full_data=full_data.drop('WindSpeed9am',axis=1)
full_data=full_data.drop('WindSpeed3pm',axis=1)
full_data=full_data.drop('Cloud9am',axis=1)
full_data=full_data.drop('Cloud3pm',axis=1)

# %%
msno.bar(full_data[full_data['Location']=='PearceRAAF'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='AliceSprings'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Darwin'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Uluru'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Katherine'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Launceston'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Hobart'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='SalmonGums'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='PerthAirport'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Perth'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Witchcliffe'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Walpole'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Albany'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Woomera'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Nuriootpa'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='MountGambier'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Adelaide'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Townsville'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='GoldCoast'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Cairns'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Brisbane'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Dartmoor'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Watsonia'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Portland'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Nhil'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Mildura'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Melbourne'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='MelbourneAirport'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Sale'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Bendigo'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Ballarat'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='MountGinini'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Tuggeranong'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Canberra'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Wollongong'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Williamtown'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='WaggaWagga'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='SydneyAirport'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Sydney'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Richmond'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Penrith'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='NorfolkIsland'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='NorahHead'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Newcastle'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Moree'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='CoffsHarbour'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Cobar'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='BadgerysCreek'], figsize=(20,5), fontsize=12);

# %%
msno.bar(full_data[full_data['Location']=='Albury'], figsize=(20,5), fontsize=12);
